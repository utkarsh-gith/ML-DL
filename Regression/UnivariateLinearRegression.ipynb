# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# x_train is the input variable (size in 1000 square feet) &
# y_train is the target (price in 1000s of dollars)

# %%
x_train = np.array([1,2,3])
y_train = np.array([100,200,300])

# %%
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1 2 3]
# y_train = [100 200 300]

# %% [markdown]
# x_train.shape returns a python tuple with an entry for each dimension. x_train.shape[0] is the length of the array and number of examples

# %%
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"m : {m}")
# Out:
# x_train.shape: (3,)
# m : 3

# %%
x1_train = np.array([[1, 2], [3, 4], [5, 6]])

z = x1_train.shape
a, b = x1_train.shape

print(f"a: {a}, b: {b}")
z
# Out:
# a: 3, b: 2
# (3, 2)

# %%
#or use len function
m = len(x_train)
print(f"Number of training examples is: {m}")
# Out:
# Number of training examples is: 3

# %%
for i in range(m):
    print(f"{i}. x_train: {x_train[i]}, y_train: {y_train[i]}")
# Out:
# 0. x_train: 1, y_train: 100
# 1. x_train: 2, y_train: 200
# 2. x_train: 3, y_train: 300

# %% [markdown]
# You can plot these two points using the scatter() function in the matplotlib library, as shown in the cell below.
# The function arguments marker and c show the points as red crosses (the default is blue dots).

# %%
plt.scatter(x_train, y_train, marker = 'x', c = 'r')
plt.title("House Prices")
plt.xlabel("House area(1000 sq m)")
plt.ylabel("Price(in $100K)")
plt.show()

# %%
w = 100
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %%
def compute_predictions(x, w, b):
    
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b;
    return f_wb

# %%
temp = compute_predictions(x_train,w,b)

plt.plot(x_train,temp,c = 'b', label = "Our Prediction")
plt.scatter(x_train, y_train, marker = 'x', c = 'r', label = "Actual values")
plt.xlabel("House area(1000 sq m)")
plt.ylabel("Price(in $100K)")
plt.show()
